# %% [markdown]
# # Lab 1 - Pandas Intro

# %%
import pandas as pd

movies_df = pd.read_csv("movie.csv")
movies_df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# ## Questions

# %% [markdown]
# DUE SEPT 9

# %%
import pandas as pd
#import csv
#movies_df = pd.read_csv('movie.csv')

# %% [markdown]
# **0.** What is the average IMDB Score of all the movies?

# %%
# attribute acccess (dot notation)

average_rating = movies_df['imdb_score'].mean()
average_rating
# Out:
# 6.4374288039056085

# %% [markdown]
# **1.** How many movies have "Star Wars" in the movie_title field?

# %%
movies_df = pd.read_csv("movie.csv")
#x = 'movie_title'
#if 'movie_title' == 'Star Wars':
#    print(x)

#movies_df['movie_title'].value_counts()
# example: data['column_name'].value_counts()


starwars = movies_df['movie_title'].str.contains('Star Wars')


starwars.sum()
#instead of using .value_counts (returns True/False) use sum
# Out:
# 8

# %% [markdown]
# **2.** Which movie has the highest IMDB Score? What is that score?

# %%
#high_imdb = movies_df['imdb_score'].max()
#print(high_imdb)
#high_imdb = movies_df.imdb_score.max()

#or

high_imdb = movies_df.sort_values('imdb_score', ascending = False)
high_imdb
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 2725  Color        John Blanchard                     NaN      65.0
# 1920  Color        Frank Darabont                   199.0     142.0
# 3402  Color  Francis Ford Coppola                   208.0     175.0
# 2779  Color                   NaN                    53.0      55.0
# 4312    NaN        John Stockwell                     2.0      90.0
# ...     ...                   ...                     ...       ...
# 2266  Color             Bob Clark                    32.0      88.0
# 2240  Color       Jason Friedberg                   111.0      88.0
# 4498  Color         A. Raven Cruz                     3.0      97.0
# 1126  Color     Lawrence Kasanoff                    12.0      91.0
# 2789  Color            Jon M. Chu                    84.0     115.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 2725                      0.0                   176.0    Andrea Martin
# ...

# %% [markdown]
# **3**. Which movie has the lowest IMDB Score? What is that score?

# %%
#low_imdb = movies_df['imdb_score'].min()
#low_imdb

low_imdb = movies_df.sort_values('imdb_score')
low_imdb
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 2789  Color            Jon M. Chu                    84.0     115.0
# 1126  Color     Lawrence Kasanoff                    12.0      91.0
# 2240  Color       Jason Friedberg                   111.0      88.0
# 2266  Color             Bob Clark                    32.0      88.0
# 4498  Color         A. Raven Cruz                     3.0      97.0
# ...     ...                   ...                     ...       ...
# 4312    NaN        John Stockwell                     2.0      90.0
# 2779  Color                   NaN                    53.0      55.0
# 3402  Color  Francis Ford Coppola                   208.0     175.0
# 1920  Color        Frank Darabont                   199.0     142.0
# 2725  Color        John Blanchard                     NaN      65.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 2789                    209.0                    41.0    Sean Kingston
# ...

# %% [markdown]
# **4.** For each director, how many movies have they directed (from this dataset)?

# %%
#directors = {}
#director_val = movies_df[(movies_df.director_name & movie_title.value_counts())]

movies_df.director_name.value_counts()
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Martin Scorsese     20
# Clint Eastwood      20
# Ridley Scott        16
#                     ..
# John Putch           1
# Luca Guadagnino      1
# Sam Fell             1
# Dan Fogelman         1
# Daniel Hsia          1
# Name: director_name, Length: 2397, dtype: int64

# %% [markdown]
# **5.** What's the average duration of Action movies?

# %%
#action_average = movies_df['genres'].mean()
#action_average
#action_average == ['Action']
#----------------------------------------------------
####find average duration using .mean(),###
####of action movies ['genre'] == ['Action']###
#----------------------------------------------------

#this lists all genres
x = movies_df['genres']
x
#----------------------------------------------------
#how many movies have are action?:
action_average = movies_df['genres'].str.contains('Action').value_counts()
#dont use value counts( for this one)
action_average
#----------------------------------------------------
#average duration of ALL movies
duration = movies_df['duration'].mean()
duration
#----------------------------------------------------
#average duration of ACTION movies:



#THIS IS THE ANSWER I SWEAR VVVVVVVVVVVVVVV
movies_df[movies_df['genres'].str.contains('Action')].duration.mean()
# Out:
# 110.67657657657658

# %% [markdown]
# **6.** Which PG-13 movie had the biggest budget?

# %%
#content_rating & budget
#x = movies_df['content_rating']== 'PG-13'
#y = movies_df['budget'].max()


#how to put this all together?????

movies_df[movies_df['content_rating'] == 'PG-13'].sort_values('budget', ascending = False)
# Out:
#                 color    director_name  num_critic_for_reviews  duration  \
# 2294            Color   Hayao Miyazaki                   174.0     134.0
# 2305            Color  Katsuhiro Ôtomo                   105.0     103.0
# 3779            Color     Carlos Saura                    35.0     115.0
# 1               Color   Gore Verbinski                   302.0     169.0
# 5               Color   Andrew Stanton                   462.0     132.0
# ...               ...              ...                     ...       ...
# 4679  Black and White    Stacy Peralta                    86.0      91.0
# 4754            Color     Jeff Nichols                    85.0      92.0
# 4814            Color      Eric Bugbee                     2.0      98.0
# 4835            Color    Peter Chelsom                    57.0     100.0
# 4914            Color      Daniel Hsia                    14.0     100.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# ...

# %% [markdown]
# **7.** How many movies were made in each year (title_year)?

# %%
#yearly_movies = movies_df[['movie_title', 'title_year']]
#yearly_movies

#How to do this pandas style? this is copied from last assignment.



movies_df['title_year'].value_counts()
# Out:
# 2009.0    253
# 2014.0    243
# 2006.0    233
# 2013.0    231
# 2010.0    225
#          ...
# 1932.0      1
# 1916.0      1
# 1934.0      1
# 1925.0      1
# 1920.0      1
# Name: title_year, Length: 91, dtype: int64

# %% [markdown]
# **8.** How many movies had more than 10000 movie_facebook_likes?

# %%
x = movies_df[movies_df['movie_facebook_likes'] > 10000].count()
x.max()
# Out:
# 1022

# %% [markdown]
# **9.** How many movies have "Tom Hanks" (as actor1, actor2, or actor3)?

# %%
mask = (
     (movies_df.actor_1_name == "Tom Hanks") |
     (movies_df.actor_2_name == "Tom Hanks") |
     (movies_df.actor_3_name == "Tom Hanks")
     )
#mask = movies_df.actor_1_name.isin(['Kevin Hart', 'Dwayne Johnson'])
#mask

movies_df[mask].movie_title.count()
#use count to grt a numnr( it is the #of rows lol)
# Out:
# 28

# %% [markdown]
# **10.**  What are the movies and number of voted users (num_voted_users) for movies that have less than 2 faces in the poster (facenumber_in_poster)?

# %%
#if facenumber_in_poster < 2, list name of movie + num_voted_users
movies_df[['movie_title', 'num_voted_users']][movies_df['facenumber_in_poster'] < 2]
# Out:
#                                      movie_title  num_voted_users
# 0                                         Avatar           886204
# 1       Pirates of the Caribbean: At World's End           471220
# 2                                        Spectre           275868
# 3                          The Dark Knight Rises          1144337
# 4     Star Wars: Episode VII - The Force Awakens                8
# ...                                          ...              ...
# 4909                             The Mongol King               36
# 4910                                   Newlyweds             1338
# 4912                               The Following            73839
# 4913                        A Plague So Pleasant               38
# 4915                           My Date with Drew             4285
#
# [3313 rows x 2 columns]

# %% [markdown]
# **11.** What are the directors and number of director facebook likes for movies made beteween 2000 and 2004 (inclusive) sorted in descending order of director facebook likes?

# %%
#made between: [2000:2004] 

movies_df[['director_name', 'director_facebook_likes', 'title_year']][
    (movies_df['title_year'] >= 2000) & (movies_df['title_year'] <= 2004)
    ]
# Out:
#         director_name  director_facebook_likes  title_year
# 31          Sam Raimi                      0.0      2004.0
# 91    Robert Zemeckis                      0.0      2004.0
# 94    Jonathan Mostow                     84.0      2003.0
# 100         Rob Cohen                    357.0      2001.0
# 111       Michael Bay                      0.0      2001.0
# ...               ...                      ...         ...
# 4899  Olivier Assayas                    107.0      2004.0
# 4900     Jafar Panahi                    397.0      2000.0
# 4903     Tadeo Garcia                      5.0      2004.0
# 4906    Shane Carruth                    291.0      2004.0
# 4915         Jon Gunn                     16.0      2004.0
#
# [932 rows x 3 columns]

# %% [markdown]
# 12.What are the missing values (NaN)?

# %%
# movies_df.movie_facebook_likes.notna().sum()
# movies_df
#what to do: 
#   replace missing values with the average or median of that column.

movies_df.duration.isna().sum()/ len(movies_df)
movies_df.duration.fillna(movies_df.duration.median())

movies_df.loc[4].duration
# Out:
# nan
